# %% [markdown]
# <a href="https://colab.research.google.com/github/jvrupp/EstatisticaML/blob/main/CursoDeEstatisticaPosicaoEDispersao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Media, Moda ,Mediana

# %%
import numpy as np
import statistics
from scipy import stats
import math
import pandas as pd

# %%
dados = np.array([150, 151, 152, 152, 153, 154, 155, 155, 155, 155, 156, 156,156,156,156, 156,
                  157, 158, 158, 160, 160, 160, 160, 160, 161, 161, 161, 161, 162,
                  163, 163, 164, 164, 164, 165, 166, 167, 168, 168, 169, 170, 172,
                  173])

# %%
freq=[]
for v,f in zip(np.unique(dados,return_counts=True)[0],np.unique(dados,return_counts=True)[1]):
  freq.append((f,v))
sorted(freq)[-1][1]
# Out:
# 156

# %%
np.median(dados)
# Out:
# 160.0

# %%
np.mean(dados)
# Out:
# 160.06976744186048

# %% [markdown]
# # Media aritimetica Ponderada

# %%
pesos=np.array([1,2,3,4])
notas=np.array([7,2,3,8])

# %%
media_ponderada=(notas*pesos).sum()/pesos.sum()

# %%
media_ponderada
# Out:
# 5.2

# %%
dados = {'inferior': [150, 154, 158, 162, 166, 170],
         'superior': [154, 158, 162, 166, 170, 174],
         'fi': [5, 9, 11, 7, 5, 3]}
dados=pd.DataFrame(dados)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dados
# Out:
#    inferior  superior  fi
# 0       150       154   5
# 1       154       158   9
# 2       158       162  11
# 3       162       166   7
# 4       166       170   5
# 5       170       174   3

# %%
def get_estatisticas(dataframe):
  media = dataset['fi.xi'].sum() / dataset['fi'].sum()
  moda = dataset[dataset['fi'] == dataset['fi'].max()]['xi'].values[0]

  fi_2 = dataset['fi'].sum() / 2
  limite_inferior, frequencia_classe, id_frequencia_anterior = 0, 0, 0
  for i, linha in enumerate(dataset.iterrows()):
    limite_inferior = linha[1][0]
    frequencia_classe = linha[1][2]
    id_frequencia_anterior = linha[0]
    if linha[1][5] >= fi_2:
      id_frequencia_anterior -= 1
      break
  Fi_anterior = dataset.iloc[[id_frequencia_anterior]]['Fi'].values[0]
  mediana = limite_inferior + ((fi_2 - Fi_anterior) * 4) / frequencia_classe

  return media, moda, mediana

# %% [markdown]
# Media geometrica

# %%
from scipy.stats.mstats import gmean
from scipy.stats.mstats import hmean

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
gmean(dados)
# Out:
# 159.9679505112537

# %%
hmean(dados)
# Out:
# 159.86695515868146

# %%
def QM(dados):
  quadrados = [x**2 for x in dados]
  razao=sum(quadrados)/len(quadrados)
  return math.sqrt(razao)

# %%
QM(dados)
# Out:
# 160.17236355411512

# %% [markdown]
# Quartis

# %%
dados_impar = [150, 151, 152, 152, 153, 154, 155, 155, 155]

# %%
metade=math.floor(len(dados_impar)/2)#50%
dados_impar[metade]
# Out:
# 153

# %%
esquerda=dados_impar[:metade]
np.median(esquerda)
# Out:
# 151.5

# %%
direita=dados_impar[metade+1:]
np.median(direita)
# Out:
# 155.0

# %%
np.quantile(dados,0.25),np.quantile(dados,0.50),np.quantile(dados,0.75)
# Out:
# (156.0, 160.0, 164.0)

# %%
dados=pd.DataFrame(dados)

# %%
dados.describe()
# Out:
#                 0
# count   43.000000
# mean   160.069767
# std      5.799817
# min    150.000000
# 25%    156.000000
# 50%    160.000000
# 75%    164.000000
# max    173.000000

# %%
np.quantile(dados,0.5)
# Out:
# 160.0

# %%
np.percentile(dados,90)#mediana de 5% da base de dados
# Out:
# 168.0

# %% [markdown]
# Exercicio

# %%
census=pd.read_csv('/content/drive/MyDrive/EstatisticaDados/census.csv')

# %%
census['age'].mean()
# Out:
# 38.58164675532078

# %%
hmean(census['age'])
# Out:
# 33.91874139089839

# %%
gmean(census['age'])
# Out:
# 36.210879158177256

# %%
QM(census['age'])
# Out:
# 40.9218664329987

# %%
census['age'].median()
# Out:
# 37.0

# %%
freq=[]
for v,f in zip(np.unique(census['age'],return_counts=True)[0],np.unique(census['age'],return_counts=True)[1]):
  freq.append((f,v))
sorted(freq)[-1][1]
# Out:
# 36

# %% [markdown]
# Amplitude amostral e diferenca interquartil

# %%
dados = np.array([150, 151, 152, 152, 153, 154, 155, 155, 155, 155, 156, 156,156,156,156, 156,
                  157, 158, 158, 160, 160, 160, 160, 160, 161, 161, 161, 161, 162,
                  163, 163, 164, 164, 164, 165, 166, 167, 168, 168, 169, 170, 172,
                  173])
amplitude_total=dados[-1]-dados[0]
amplitude_total
Q1=np.quantile(dados,0.25)
Q2=np.quantile(dados,0.50)
Q3=np.quantile(dados,0.75)
print(Q3-Q1)
# Out:
# 8.0

# %%
inferior=Q1  - (1.5 *(Q3-Q1) )
inferior
# Out:
# 144.0

# %%
duperior=Q3  + (1.5 *(Q3-Q1) )
duperior
# Out:
# 176.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dados.var()
# Out:
# 32.85559762033532

# %%
dados+dados.std()
# Out:
# array([155.73198025, 156.73198025, 157.73198025, 157.73198025,
#        158.73198025, 159.73198025, 160.73198025, 160.73198025,
#        160.73198025, 160.73198025, 161.73198025, 161.73198025,
#        161.73198025, 161.73198025, 161.73198025, 161.73198025,
#        162.73198025, 163.73198025, 163.73198025, 165.73198025,
#        165.73198025, 165.73198025, 165.73198025, 165.73198025,
#        166.73198025, 166.73198025, 166.73198025, 166.73198025,
#        167.73198025, 168.73198025, 168.73198025, 169.73198025,
#        169.73198025, 169.73198025, 170.73198025, 171.73198025,
#        172.73198025, 173.73198025, 173.73198025, 174.73198025,
#        175.73198025, 177.73198025, 178.73198025])

# %%
dados.std()
# Out:
# 5.731980252961041

# %% [markdown]
# Coeficiente de variacao

# %%
CV = (dados.std()/dados.mean())*100

# %%
CV
# Out:
# 3.5809262077193775

# %% [markdown]
# Testes com algoritimos de classificaçao
